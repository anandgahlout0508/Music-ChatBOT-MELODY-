# %%
import pyttsx3 as pts
import speech_recognition as sr

recog=sr.Recognizer()
engine=pts.init()
voices=engine.getProperty("voices")
engine.setProperty('voice', voices[1].id)
engine.setProperty("volume",1)
engine.setProperty("rate",125)

print("hello melody here, what's your name")
engine.say("hello melody here, what's your name")
engine.runAndWait()

with sr.Microphone() as source:
    print("speak now")
    recog.adjust_for_ambient_noise(source)
    recog.pause_threshold = 1
    audio = recog.listen(source)


print("recognizing")
try:
    output1 = recog.recognize_google(audio)
    print("hello " + output1 + " My name is melody,I am your music chat bot . I can help you in understanding what is music and benefits of listening it . I can also suggests you some musics depending on your mood, you will feel good")
    engine.say("hello " + output1 + " My name is melody,I am your music chat bot . I can help you in understanding what is music and benefits of listening it . I can also suggests you some musics depending on your mood, you will feel good")
    engine.runAndWait()
except:
    print("cannot hear you clearly but nice to meet you . My name is melody,I am your music chat bot.I can help you in understanding what is music and benefits of listening it . I can also suggests you some musics depending on your mood, you will feel good")
    engine.say("cannot hear you clearly but nice to meet you . My name is melody,I am your music chat bot.I can help you in understanding what is music and benefits of listening it . I can also suggests you some musics depending on your mood, you will feel good")
    engine.runAndWait()

    #here you can ask questions like what is music, what are benefits of music and also you can say i would like to listen music
    #it will provide you list of 4-5 songs depending on your mood like sad song,inspirational songs,romantic songs,workout songs and sifi songs.
    #it will go on asking you , if you want to exit say leave. 

while True: 
    with sr.Microphone() as source:    
        print("microphone is started please say something:")
        engine.say("microphone is started please say something:")
        engine.runAndWait()
        recog.adjust_for_ambient_noise(source)
        recog.pause_threshold = 1
        audio=recog.listen(source)
    try: 
        text=recog.recognize_google(audio)
        text=text.lower()
        if(text=="leave"):
            print("Thank u have a nice day")
            engine.say("Thank u have a nice day")
            engine.runAndWait()
            break
        elif(text=="what is music"):
            a="Music is the art of arranging sounds in time to produce a composition through the elements of melody, harmony ,rhythm and timbre . It is one of the universal cultural aspects of all human societies."
            print(a)
            engine.say(a)
            engine.runAndWait()
        elif(text=="what are benefits of listening music"):
            a="It elevates mood , reduces stress , stimulates memories , strenghthen learning"
            print(a)
            engine.say(a)
            engine.runAndWait()
        elif(text=="i would like to listen music"):
            with sr.Microphone() as source:
                print("Which type of songs would you like to listen")
                engine.say("which type of songs would you like to listen")
                engine.runAndWait()
                recog.adjust_for_ambient_noise(source)
                recog.pause_threshold = 1
                audio1=recog.listen(source)
            try:
                text1=recog.recognize_google(audio1)
                text1=text1.lower()
                if(text1=="sad songs"):
                    with sr.Microphone() as source:
                        print("say yes for hollywood music and no for bollywood music suggestions")
                        engine.say("say yes for hollywood music and no for bollywood music suggestions")
                        engine.runAndWait()
                        print("speak now..")
                        recog.adjust_for_ambient_noise(source)
                        recog.pause_threshold = 1
                        audio2= recog.listen(source)
                    try:
                        text2=recog.recognize_google(audio2)
                        text2=text2.lower()
                        if(text2=="yes"):
                            print("you can refer to songs like above and beyond , concrete angel , southern sun , raise your weapon , waiting and many more.")
                            engine.say("you can refer to songs like above and beyond , concrete angel , southern sun , raise your weapon , waiting and many more")
                            engine.runAndWait()
                        elif(text2=="no"):
                            print("you can refer to songs like main jahan rahoon , mujh mein tu , barishein , abhi abhi and many more")
                            engine.say("you can refer to songs like main jahan rahoon , mujh mein tu , barishein , abhi abhi and many more")
                            engine.runAndWait()
                    except:
                        print("could not get it. please start again.")
                        engine.say("could not get it . please start again ")
                        engine.runAndWait()
                elif(text1=="inspirational songs"):
                    with sr.Microphone() as source:
                        print("say yes for hollywood music and no for bollywood music suggestions")
                        engine.say("say yes for hollywood music and no for bollywood music suggestions")
                        engine.runAndWait()
                        print("speak now..")
                        recog.adjust_for_ambient_noise(source)
                        recog.pause_threshold = 1
                        audio2= recog.listen(source)
                    try:
                        text2=recog.recognize_google(audio2)
                        text2=text2.lower()
                        
                        if(text2=="yes"):
                            print("you can refer to songs like stronger , don't stop believing , skyscrapper , it is my life and many more")
                            engine.say("you can refer to songs like stronger , don't stop believing , skyscrapper , it is my life and many more")
                            engine.runAndWait()
                        elif(text2=="no"):
                            print("you can refer to songs like wake up sid , lakshya , aashayein , brothers anthem and many more")
                            engine.say("you can refer to songs like wake up sid , lakshya , aashayein , brothers anthem and many more")
                            engine.runAndWait()
                    except:
                        print("could not get it. please start again.")
                        engine.say("could not get it . please start again ")
                        engine.runAndWait()
                elif(text1=="romantic songs"):
                    with sr.Microphone() as source:
                        print("say yes for hollywood music and no for bollywood music suggestions")
                        engine.say("say yes for hollywood music and no for bollywood music suggestions")
                        engine.runAndWait()
                        print("speak now..")
                        recog.adjust_for_ambient_noise(source)
                        recog.pause_threshold = 1
                        audio2=recog.listen(source)
                    try:
                        text2=recog.recognize_google(audio2)
                        text2=text2.lower()
                        if(text2=="yes"):
                            print("you can refer to songs like we belong together , hold you in my arms , love on top , crazy for you and many more")
                            engine.say("you can refer to songs like we belong together , hold you in my arms , love on top , crazy for you and many more")
                            engine.runAndWait()
                        elif(text2=="no"):
                            print("you can refer to songs like tum se hi , quaafirana , agar tum saath ho , dil diyan gallan and many more ")
                            engine.say("you can refer to songs like tum se hi , quaafirana , agar tum saath ho , dil diyan gallan and many more")
                            engine.runAndWait()
                    except:
                        print("could not get it. please start again.")
                        engine.say("could not get it . please start again ")
                        engine.runAndWait()
                elif(text1=="workout songs"):
                    with sr.Microphone() as source:
                        print("say yes for hollywood music and no for bollywood music suggestions")
                        engine.say("say yes for hollywood music and no for bollywood music suggestions")
                        engine.runAndWait()
                        print("speak now..")
                        recog.adjust_for_ambient_noise(source)
                        recog.pause_threshold = 1
                        audio2= recog.listen(source)
                    try:
                        text2=recog.recognize_google(audio2)
                        text2=text2.lower()
                        if(text2=="yes"):
                            print("you can refer to songs like no pain no gain , till i collapse , motivation , eye of the tiger and many more ")
                            engine.say("you can refer to songs like no pain no gain , till i collapse , motivation , eye of the tiger and many more")
                            engine.runAndWait()
                        elif(text2=="no"):
                            print("you can refer to songs like zinda , brothers anthem , ziddi dil , rock on , bhaag milkha bhaag and many more")
                            engine.say("you can refer to songs like zinda , brothers anthem , ziddi dil , rock on , bhaag milkha bhaag and many more")
                            engine.runAndWait()
                    except:
                        print("could not get it. please start again.")
                        engine.say("could not get it . please start again ")
                        engine.runAndWait()
                elif(text1=="sufi songs"):
                    print("you can refer to songs like khwaja mere khwaja , kun faya kun , maula re maula , rangrez and many more")
                    engine.say("you can refer to songs like khwaja mere khwaja , kun faya kun , maula re maula , rangrez and many more")
                    engine.runAndWait()
            except:
                print("sorry cannot find your feed")
                engine.say("sorry cannot find your feed")
                engine.runAndWait()
    except:
        print("please speak again,could not get it or if you want to end say leave")
        engine.say("Please speak again,could not get it or if you want to end say leave")
        engine.runAndWait()
# Out:
# hello melody here, what's your name
# speak now
# recognizing
# hello Anand My name is melody,I am your music chat bot . I can help you in understanding what is music and benefits of listening it . I can also suggests you some musics depending on your mood, you will feel good
# microphone is started please say something:
# Which type of songs would you like to listen
# say yes for hollywood music and no for bollywood music suggestions
# speak now..
# you can refer to songs like above and beyond , concrete angel , southern sun , raise your weapon , waiting and many more.
# microphone is started please say something:
# please speak again,could not get it or if you want to end say leave
# microphone is started please say something:
# Thank u have a nice day
